# %%
def format_easier_variant_prompt(question: str) -> str:
    prompt = f"""
    You are an expert physics teacher. Given a challenging physics question, create 2 easier variants 
    of the same problem that help build understanding toward the original question.
    The variants should:
    1. Focus on simpler aspects of the same concept
    2. Use round numbers or simpler scenarios
    3. Break down complex calculations into smaller steps
    
    Original Question:
    {question}

    Format your response as:
    <variant>
    [First easier version of the question]
    </variant>
    <variant>
    [Second easier version of the question]
    </variant>
    """
    return prompt

def extract_variants(text: str) -> list[str]:
    """
    Extract variant questions from text that contains XML-like tags.
    Returns a list of variant questions.
    """
    import re
    
    # Pattern to match variants
    pattern = r'<variant\>(.*?)</variant\>'
    
    # Find all matches in the text
    matches = re.findall(pattern, text, re.DOTALL)
    
    # Clean up whitespace in the results
    variants = [v.strip() for v in matches]
    
    return variants

# Example usage:
variant_prompt = format_easier_variant_prompt(question)
variants_text = await generate_text(model="gpt-4o-mini", prompt=variant_prompt)
variants = extract_variants(variants_text)

# %%
for variant in variants:
    print(variant)
    print("------------")
# Out:
# Consider the equation \( \cos(x) + \sin(x) = 0 \). Compute the number of solutions \( x \in [0, 2\pi] \).
# ------------
# Now, solve the equation \( \cos(x) = -\sin(x) \) for \( x \in [0, \pi] \). How many solutions can you find in this interval?
# ------------

# %%
import numpy as np
import math

def f(x):
    return math.cos(x) + math.sin(x)

def count_roots(num_points=1000000):
    # Create a grid of points between 0 and π
    xs = np.linspace(0, math.pi, num_points)
    
    # Evaluate f(x) over the grid
    f_values = [f(x) for x in xs]
    
    count = 0
    # Look for sign changes between consecutive points
    for i in range(len(f_values) - 1):
        if f_values[i] * f_values[i+1] < 0:
            count += 1
    return count

if __name__ == '__main__':
    num_solutions = count_roots()
    print("Number of solutions in [0, π]:", num_solutions)
# Out:
# Number of solutions in [0, π]: 1

# %%
from lib.question_generator import QuestionGenerator
passage = """
In calculus, a sequence is a list of numbers in a definite order. 
The limit of a sequence {an} is the value that the terms of the sequence approach as n approaches infinity.
For example, the sequence an = 1/n approaches 0 as n approaches infinity.
"""

# Create question generator
generator = QuestionGenerator()

# Generate questions with verification
print("Generating questions with verification...")
verified_questions = await generator.generate_questions(
    passage,
    num_questions=10,
    verify=True,
    verification_threshold=0.8
)

print(f"\nGenerated {len(verified_questions)} verified questions:")
for i, qa in enumerate(verified_questions, 1):
    print(f"\nQuestion {i}:")
    print(qa.question)
    print("\nSolution:")
    print(qa.solution)
    print("\nHints:")
    for j, hint in enumerate(qa.hints or [], 1):
        print(f"{j}. {hint}")
    print("-" * 80)
# Out:
# [autoreload of lib.question_generator.generator failed: Traceback (most recent call last):
#   File "/Users/tamassimonds/Library/Python/3.9/lib/python/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/tamassimonds/Library/Python/3.9/lib/python/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/tamassimonds/Documents/Code/Ai/BeyondNextTokenPrediction/lib/question_generator/generator.py", line 7, in <module>
#     from .models import QuestionAnswer, ValidationResult, QuestionDomain
# ImportError: cannot import name 'QuestionDomain' from 'lib.question_generator.models' (/Users/tamassimonds/Documents/Code/Ai/BeyondNextTokenPrediction/lib/question_generator/models.py)
# ]
# Generating questions with verification...
# Found 9 question-answer pairs in text
# Model Answer length: 187
# Ground Truth Answer length: 2156
# Model Answer length: 191
# Ground Truth Answer length: 2332
# Model Answer length: 138
# Ground Truth Answer length: 1479
# Model Answer length: 165
# Ground Truth Answer length: 1576
# Model Answer length: 159
# Ground Truth Answer length: 1379
# Model Answer length: 134
# Ground Truth Answer length: 1714
# Model Answer length: 200
# Ground Truth Answer length: 2946
# Model Answer length: 158
# Ground Truth Answer length: 2017
# Model Answer length: 173
# Ground Truth Answer length: 1741
#
# Generated 6 verified questions:
#
# Question 1:
# What is the limit of the sequence defined by an = 1/n as n approaches infinity?
#
# Solution:
# The limit of the sequence defined by an = 1/n as n approaches infinity is 0. As n increases, the value of 1/n gets closer and closer to 0.
#
# Hints:
# 1. Start by understanding what happens to the term \( a_n = \frac{1}{n} \) as \( n \) gets larger and larger. Consider what happens to the value of \( \frac{1}{n} \) when \( n \) approaches infinity.
# 2. Recall the definition of a limit: you want to determine what value \( a_n \) approaches as \( n \) increases without bound. Think about how the fraction behaves as the denominator increases.
# 3. It might help to visualize or calculate a few values of \( a_n \) for large \( n \) (like \( n = 10, 100, 1000 \)) to see if you can identify a pattern or trend in the sequence.
# --------------------------------------------------------------------------------
#
# Question 2:
# How does the sequence an = 1/n behave as n increases?
#
# Solution:
# As n increases, the sequence an = 1/n decreases in value and approaches 0. This means that the terms of the sequence get smaller and closer to 0 as n becomes larger.
#
# Hints:
# 1. Start by evaluating the sequence for a few specific values of n, such as n = 1, 2, 3, and
# 2. This will help you see how the terms of the sequence change as n increases.
# 3. Consider the concept of limits in calculus. Think about what happens to the value of an = 1/n as n approaches infinity. What do you know about the behavior of fractions when the denominator becomes very large?
# 4. Reflect on the definition of convergence. Does the sequence approach a specific value as n increases, or does it continue to change? This will help you determine the overall behavior of the sequence.
# --------------------------------------------------------------------------------
#
# Question 3:
# Can you provide an example of a sequence and its limit?
#
# Solution:
# An example of a sequence is an = 1/n. The limit of this sequence as n approaches infinity is 0, as the terms of the sequence get closer to 0 with increasing n.
#
# Hints:
# 1. Start by thinking about what a sequence is. A sequence is simply a list of numbers that follow a specific pattern or rule. Consider writing down a few terms of a sequence to see how they behave as you progress.
# 2. Focus on the concept of limits. A limit describes the value that a sequence approaches as the number of terms goes to infinity. Think about how you can express this mathematically, perhaps using the notation \( \lim_{n \to \infty} a_n \) where \( a_n \) represents the terms of your sequence.
# 3. Try to find a simple sequence, like a geometric or arithmetic sequence, and calculate its limit. For example, consider sequences that converge to a specific number, such as \( \frac{1}{n} \) or \( \frac{n}{n+1} \), and see what happens as \( n \) increases.
# --------------------------------------------------------------------------------
#
# Question 4:
# What happens to the terms of the sequence an = 1/n as n approaches infinity?
#
# Solution:
# As n approaches infinity, the terms of the sequence an = 1/n approach the value of 0. This indicates that the sequence converges to 0.
#
# Hints:
# 1. Start by understanding what the sequence an = 1/n looks like for different values of n. Consider calculating the first few terms of the sequence to see how they change as n increases.
# 2. Think about the concept of limits in calculus. Specifically, consider what it means for n to approach infinity and how that affects the value of 1/n.
# 3. Focus on the behavior of the fraction 1/n as n gets larger and larger. What value does it seem to be getting closer to? This will help you determine the limit of the sequence as n approaches infinity.
# --------------------------------------------------------------------------------
#
# Question 5:
# What does it mean for a sequence to converge?
#
# Solution:
# A sequence is said to converge if its terms approach a specific value (the limit) as n approaches infinity. For example, the sequence an = 1/n converges to 0.
#
# Hints:
# 1. Start by reviewing the definition of convergence in the context of sequences. Think about what it means for the terms of a sequence to get closer to a specific value as you progress through the sequence.
# 2. Consider the concept of a limit. What does it mean for the limit of a sequence to exist? You might want to look at the formal definition of a limit and how it applies to sequences.
# 3. Focus on examples of convergent and divergent sequences. Analyzing these examples can help you understand the behavior of sequences and what it means for them to converge to a particular value.
# --------------------------------------------------------------------------------
#
# Question 6:
# Is the sequence an = 1/n bounded? If so, what are its bounds?
#
# Solution:
# Yes, the sequence an = 1/n is bounded. The terms of the sequence are always positive and decrease towards 0, so the bounds are 0 (lower bound) and 1 (upper bound, when n=1).
#
# Hints:
# 1. Start by understanding what it means for a sequence to be bounded. A sequence is bounded if there are real numbers \( M \) and \( m \) such that \( m \leq a_n \leq M \) for all \( n \). Think about the values of \( a_n = \frac{1}{n} \) as \( n \) increases.
# 2. Consider the behavior of the sequence as \( n \) approaches infinity. What happens to the value of \( a_n \) in this case? This will help you determine if there is a lower bound and an upper bound for the sequence.
# 3. Once you have an idea of the limits of the sequence, try to identify specific values for \( M \) and \( m \) that satisfy the bounded condition. Remember to check if the sequence ever reaches these bounds or if it only approaches them.
# --------------------------------------------------------------------------------

# %%
for question in verified_questions:
    print(question.source)
    print(question.question)
    print(question.solution)
    print(question.hints)
    
    print("-" * 80)
print(len(verified_questions))
# Out:
# In calculus, a sequence is a list of numbers in a definite order.
# The limit of a sequence {an} is the value that the terms of the sequence approach as n approaches infinity.
# For example, the sequence an = 1/n approaches 0 as n approaches infinity.
# What is the limit of the sequence defined by an = 1/n as n approaches infinity?
# The limit of the sequence defined by an = 1/n as n approaches infinity is 0. As n increases, the value of 1/n gets closer and closer to 0.
# ['Start by understanding what happens to the term \\( a_n = \\frac{1}{n} \\) as \\( n \\) gets larger and larger. Consider what happens to the value of \\( \\frac{1}{n} \\) when \\( n \\) approaches infinity.', 'Recall the definition of a limit: you want to determine what value \\( a_n \\) approaches as \\( n \\) increases without bound. Think about how the fraction behaves as the denominator increases.', 'It might help to visualize or calculate a few values of \\( a_n \\) for large \\( n \\) (like \\( n = 10, 100, 1000 \\)) to see if you can identify a pattern or trend in the sequence.']
# --------------------------------------------------------------------------------
# In calculus, a sequence is a list of numbers in a definite order.
# The limit of a sequence {an} is the value that the terms of the sequence approach as n approaches infinity.
# For example, the sequence an = 1/n approaches 0 as n approaches infinity.
# How does the sequence an = 1/n behave as n increases?
# As n increases, the sequence an = 1/n decreases in value and approaches 0. This means that the terms of the sequence get smaller and closer to 0 as n becomes larger.
# ['Start by evaluating the sequence for a few specific values of n, such as n = 1, 2, 3, and', 'This will help you see how the terms of the sequence change as n increases.', 'Consider the concept of limits in calculus. Think about what happens to the value of an = 1/n as n approaches infinity. What do you know about the behavior of fractions when the denominator becomes very large?', 'Reflect on the definition of convergence. Does the sequence approach a specific value as n increases, or does it continue to change? This will help you determine the overall behavior of the sequence.']
# --------------------------------------------------------------------------------
# In calculus, a sequence is a list of numbers in a definite order.
# The limit of a sequence {an} is the value that the terms of the sequence approach as n approaches infinity.
# For example, the sequence an = 1/n approaches 0 as n approaches infinity.
# Can you provide an example of a sequence and its limit?
# An example of a sequence is an = 1/n. The limit of this sequence as n approaches infinity is 0, as the terms of the sequence get closer to 0 with increasing n.
# ['Start by thinking about what a sequence is. A sequence is simply a list of numbers that follow a specific pattern or rule. Consider writing down a few terms of a sequence to see how they behave as you progress.', 'Focus on the concept of limits. A limit describes the value that a sequence approaches as the number of terms goes to infinity. Think about how you can express this mathematically, perhaps using the notation \\( \\lim_{n \\to \\infty} a_n \\) where \\( a_n \\) represents the terms of your sequence.', 'Try to find a simple sequence, like a geometric or arithmetic sequence, and calculate its limit. For example, consider sequences that converge to a specific number, such as \\( \\frac{1}{n} \\) or \\( \\frac{n}{n+1} \\), and see what happens as \\( n \\) increases.']
# --------------------------------------------------------------------------------
# In calculus, a sequence is a list of numbers in a definite order.
# The limit of a sequence {an} is the value that the terms of the sequence approach as n approaches infinity.
# For example, the sequence an = 1/n approaches 0 as n approaches infinity.
# What happens to the terms of the sequence an = 1/n as n approaches infinity?
# As n approaches infinity, the terms of the sequence an = 1/n approach the value of 0. This indicates that the sequence converges to 0.
# ['Start by understanding what the sequence an = 1/n looks like for different values of n. Consider calculating the first few terms of the sequence to see how they change as n increases.', 'Think about the concept of limits in calculus. Specifically, consider what it means for n to approach infinity and how that affects the value of 1/n.', 'Focus on the behavior of the fraction 1/n as n gets larger and larger. What value does it seem to be getting closer to? This will help you determine the limit of the sequence as n approaches infinity.']
# --------------------------------------------------------------------------------
# In calculus, a sequence is a list of numbers in a definite order.
# The limit of a sequence {an} is the value that the terms of the sequence approach as n approaches infinity.
# For example, the sequence an = 1/n approaches 0 as n approaches infinity.
# What does it mean for a sequence to converge?
# A sequence is said to converge if its terms approach a specific value (the limit) as n approaches infinity. For example, the sequence an = 1/n converges to 0.
# ['Start by reviewing the definition of convergence in the context of sequences. Think about what it means for the terms of a sequence to get closer to a specific value as you progress through the sequence.', 'Consider the concept of a limit. What does it mean for the limit of a sequence to exist? You might want to look at the formal definition of a limit and how it applies to sequences.', 'Focus on examples of convergent and divergent sequences. Analyzing these examples can help you understand the behavior of sequences and what it means for them to converge to a particular value.']
# --------------------------------------------------------------------------------
# In calculus, a sequence is a list of numbers in a definite order.
# The limit of a sequence {an} is the value that the terms of the sequence approach as n approaches infinity.
# For example, the sequence an = 1/n approaches 0 as n approaches infinity.
# Is the sequence an = 1/n bounded? If so, what are its bounds?
# Yes, the sequence an = 1/n is bounded. The terms of the sequence are always positive and decrease towards 0, so the bounds are 0 (lower bound) and 1 (upper bound, when n=1).
# ['Start by understanding what it means for a sequence to be bounded. A sequence is bounded if there are real numbers \\( M \\) and \\( m \\) such that \\( m \\leq a_n \\leq M \\) for all \\( n \\). Think about the values of \\( a_n = \\frac{1}{n} \\) as \\( n \\) increases.', 'Consider the behavior of the sequence as \\( n \\) approaches infinity. What happens to the value of \\( a_n \\) in this case? This will help you determine if there is a lower bound and an upper bound for the sequence.', 'Once you have an idea of the limits of the sequence, try to identify specific values for \\( M \\) and \\( m \\) that satisfy the bounded condition. Remember to check if the sequence ever reaches these bounds or if it only approaches them.']
# --------------------------------------------------------------------------------
# 6
