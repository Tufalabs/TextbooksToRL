# %%
# !pip install docling
# Out:
# Collecting docling
#   Downloading docling-2.25.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from docling)
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: certifi>=2024.7.4 in ./venv/lib/python3.9/site-packages (from docling) (2025.1.31)
# Collecting docling-core<3.0.0,>=2.19.0 (from docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading docling_core-2.21.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting docling-ibm-models<4.0.0,>=3.4.0 (from docling)
#   Downloading docling_ibm_models-3.4.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting docling-parse<4.0.0,>=3.3.0 (from docling)
#   Downloading docling_parse-3.4.0-cp39-cp39-macosx_14_0_arm64.whl.metadata (9.5 kB)
# Collecting easyocr<2.0,>=1.7 (from docling)
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from docling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting huggingface_hub<1,>=0.23 (from docling)
#   Downloading huggingface_hub-0.29.1-py3-none-any.whl.metadata (13 kB)
# Collecting lxml<6.0.0,>=4.0.0 (from docling)
#   Downloading lxml-5.3.1-cp39-cp39-macosx_10_9_universal2.whl.metadata (3.7 kB)
# Collecting marko<3.0.0,>=2.1.2 (from docling)
#   Downloading marko-2.1.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting openpyxl<4.0.0,>=3.1.5 (from docling)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pandas<3.0.0,>=2.1.4 (from docling)
#   Downloading pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting pillow<12.0.0,>=10.0.0 (from docling)
#   Downloading pillow-11.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in ./venv/lib/python3.9/site-packages (from docling) (2.10.6)
# Collecting pydantic-settings<3.0.0,>=2.3.0 (from docling)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting pypdfium2<5.0.0,>=4.30.0 (from docling)
#   Downloading pypdfium2-4.30.1-py3-none-macosx_11_0_arm64.whl.metadata (48 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in ./venv/lib/python3.9/site-packages (from docling) (2.32.3)
# Collecting rtree<2.0.0,>=1.3.0 (from docling)
#   Downloading Rtree-1.3.0-py3-none-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting scipy<1.14.0,>=1.6.0 (from docling)
#   Using cached scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in ./venv/lib/python3.9/site-packages (from docling) (4.67.1)
# Collecting typer<0.13.0,>=0.12.5 (from docling)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.12.3->docling)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (4.12.2)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting jsonschema<5.0.0,>=4.16.0 (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading latex2mathml-3.77.0-py3-none-any.whl.metadata (14 kB)
# Collecting pyyaml<7.0.0,>=5.1 (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading PyYAML-6.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting tabulate<0.10.0,>=0.9.0 (from docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Collecting jsonlines<4.0.0,>=3.1.0 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading jsonlines-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting numpy<3.0.0,>=1.24.4 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting opencv-python-headless<5.0.0.0,>=4.6.0.66 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Collecting safetensors<1,>=0.4.3 (from safetensors[torch]<1,>=0.4.3->docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting torch<3.0.0,>=2.2.2 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading torch-2.6.0-cp39-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting torchvision<1,>=0 (from docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading torchvision-0.21.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Collecting scikit-image (from easyocr<2.0,>=1.7->docling)
#   Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting python-bidi (from easyocr<2.0,>=1.7->docling)
#   Downloading python_bidi-0.6.6-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting Shapely (from easyocr<2.0,>=1.7->docling)
#   Downloading shapely-2.0.7-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting pyclipper (from easyocr<2.0,>=1.7->docling)
#   Downloading pyclipper-1.3.0.post6-cp39-cp39-macosx_10_9_universal2.whl.metadata (9.0 kB)
# Collecting ninja (from easyocr<2.0,>=1.7->docling)
#   Downloading ninja-1.11.1.3-py3-none-macosx_10_9_universal2.whl.metadata (5.3 kB)
# Collecting filelock (from huggingface_hub<1,>=0.23->docling)
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub<1,>=0.23->docling)
#   Downloading fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in ./venv/lib/python3.9/site-packages (from huggingface_hub<1,>=0.23->docling) (24.2)
# Collecting et-xmlfile (from openpyxl<4.0.0,>=3.1.5->docling)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.9/site-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0.0,>=2.1.4->docling)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=2.1.4->docling)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.27.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.3.0->docling)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling)
#   Downloading XlsxWriter-3.2.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.2->docling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.2->docling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.2->docling) (2.3.0)
# Collecting click>=8.0.0 (from typer<0.13.0,>=0.12.5->docling)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting shellingham>=1.3.0 (from typer<0.13.0,>=0.12.5->docling)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<0.13.0,>=0.12.5->docling)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: attrs>=19.2.0 in ./venv/lib/python3.9/site-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<4.0.0,>=3.4.0->docling) (25.1.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.19.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading rpds_py-0.23.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<0.13.0,>=0.12.5->docling)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.9/site-packages (from rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (2.19.1)
# Collecting mpire[dill] (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Collecting networkx (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting sympy==1.13.1 (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading regex-2024.11.6-cp39-cp39-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting imageio>=2.33 (from scikit-image->easyocr<2.0,>=1.7->docling)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr<2.0,>=1.7->docling)
#   Downloading tifffile-2024.8.30-py3-none-any.whl.metadata (31 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr<2.0,>=1.7->docling)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.13.0,>=0.12.5->docling)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling)
#   Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting multiprocess (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading multiprocess-0.70.17-py39-none-any.whl.metadata (7.2 kB)
# Collecting dill>=0.3.9 (from multiprocess->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.19.0->docling)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading docling-2.25.1-py3-none-any.whl (145 kB)
# Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Downloading docling_core-2.21.1-py3-none-any.whl (96 kB)
# Downloading docling_ibm_models-3.4.1-py3-none-any.whl (80 kB)
# Downloading docling_parse-3.4.0-cp39-cp39-macosx_14_0_arm64.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 12.9 MB/s eta 0:00:00a 0:00:01
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading huggingface_hub-0.29.1-py3-none-any.whl (468 kB)
# Downloading lxml-5.3.1-cp39-cp39-macosx_10_9_universal2.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 13.3 MB/s eta 0:00:00a 0:00:01
# Downloading marko-2.1.2-py3-none-any.whl (42 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 12.4 MB/s eta 0:00:00a 0:00:01
# Downloading pillow-11.1.0-cp39-cp39-macosx_11_0_arm64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 13.0 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading pypdfium2-4.30.1-py3-none-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 13.1 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading Rtree-1.3.0-py3-none-macosx_11_0_arm64.whl (432 kB)
# Using cached scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
# Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading latex2mathml-3.77.0-py3-none-any.whl (73 kB)
# Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 13.5 MB/s eta 0:00:00a 0:00:01
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading PyYAML-6.0.2-cp39-cp39-macosx_11_0_arm64.whl (172 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Downloading semchunk-2.2.2-py3-none-any.whl (10 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading torch-2.6.0-cp39-none-macosx_11_0_arm64.whl (66.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 MB 13.5 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 13.3 MB/s eta 0:00:00a 0:00:01
# Downloading torchvision-0.21.0-cp39-cp39-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.7 MB/s eta 0:00:00
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 13.4 MB/s eta 0:00:00 0:00:01
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading XlsxWriter-3.2.2-py3-none-any.whl (165 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading ninja-1.11.1.3-py3-none-macosx_10_9_universal2.whl (279 kB)
# Downloading pyclipper-1.3.0.post6-cp39-cp39-macosx_10_9_universal2.whl (270 kB)
# Downloading python_bidi-0.6.6-cp39-cp39-macosx_11_0_arm64.whl (263 kB)
# Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 3.0 MB/s eta 0:00:00a 0:00:02
# Downloading shapely-2.0.7-cp39-cp39-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.8 MB/s eta 0:00:00
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.4 MB/s eta 0:00:00
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading regex-2024.11.6-cp39-cp39-macosx_11_0_arm64.whl (284 kB)
# Downloading rpds_py-0.23.1-cp39-cp39-macosx_11_0_arm64.whl (357 kB)
# Downloading tifffile-2024.8.30-py3-none-any.whl (227 kB)
# Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 12.9 MB/s eta 0:00:00
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
# Downloading multiprocess-0.70.17-py39-none-any.whl (133 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Installing collected packages: pytz, python-bidi, pyclipper, mpmath, filetype, XlsxWriter, tzdata, tabulate, sympy, soupsieve, shellingham, safetensors, rtree, rpds-py, regex, pyyaml, python-dotenv, pypdfium2, pillow, numpy, ninja, networkx, mpire, mdurl, MarkupSafe, marko, lxml, lazy-loader, latex2mathml, jsonref, jsonlines, fsspec, filelock, et-xmlfile, dill, click, tifffile, Shapely, scipy, referencing, python-pptx, python-docx, pandas, openpyxl, opencv-python-headless, multiprocess, markdown-it-py, jinja2, imageio, huggingface_hub, beautifulsoup4, torch, tokenizers, scikit-image, rich, pydantic-settings, jsonschema-specifications, typer, transformers, torchvision, semchunk, jsonschema, easyocr, docling-core, docling-parse, docling-ibm-models, docling
# Successfully installed MarkupSafe-3.0.2 Shapely-2.0.7 XlsxWriter-3.2.2 beautifulsoup4-4.13.3 click-8.1.8 dill-0.3.9 docling-2.25.1 docling-core-2.21.1 docling-ibm-models-3.4.1 docling-parse-3.4.0 easyocr-1.7.2 et-xmlfile-2.0.0 filelock-3.17.0 filetype-1.2.0 fsspec-2025.2.0 huggingface_hub-0.29.1 imageio-2.37.0 jinja2-3.1.5 jsonlines-3.1.0 jsonref-1.1.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 latex2mathml-3.77.0 lazy-loader-0.4 lxml-5.3.1 markdown-it-py-3.0.0 marko-2.1.2 mdurl-0.1.2 mpire-2.10.2 mpmath-1.3.0 multiprocess-0.70.17 networkx-3.2.1 ninja-1.11.1.3 numpy-2.0.2 opencv-python-headless-4.11.0.86 openpyxl-3.1.5 pandas-2.2.3 pillow-11.1.0 pyclipper-1.3.0.post6 pydantic-settings-2.8.1 pypdfium2-4.30.1 python-bidi-0.6.6 python-docx-1.1.2 python-dotenv-1.0.1 python-pptx-1.0.2 pytz-2025.1 pyyaml-6.0.2 referencing-0.36.2 regex-2024.11.6 rich-13.9.4 rpds-py-0.23.1 rtree-1.3.0 safetensors-0.5.3 scikit-image-0.24.0 scipy-1.13.1 semchunk-2.2.2 shellingham-1.5.4 soupsieve-2.6 sympy-1.13.1 tabulate-0.9.0 tifffile-2024.8.30 tokenizers-0.21.0 torch-2.6.0 torchvision-0.21.0 transformers-4.49.0 typer-0.12.5 tzdata-2025.1

# %%
from docling.document_converter import DocumentConverter

source = "https://arxiv.org/pdf/2408.09869"  # document per local path or URL
converter = DocumentConverter()
result = converter.convert(source)
print(result.document.export_to_markdown())  # output: "## Docling Technical Report[...]"
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/models/ds4sd/docling-models/revision/v2.1.0
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/_snapshot_download.py:155, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     148     api = HfApi(
#     149         library_name=library_name,
#     150         library_version=library_version,
#    (...)
#     153         headers=headers,
#     154     )
# --> 155     repo_info = api.repo_info(repo_id=repo_id, repo_type=repo_type, revision=revision, token=token)
#     156 except (requests.exceptions.SSLError, requests.exceptions.ProxyError):
#     157     # Actually raise for those subclasses of ConnectionError
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/hf_api.py:2734, in HfApi.repo_info(self, repo_id, revision, repo_type, timeout, files_metadata, expand, token)
#    2733     raise ValueError("Unsupported repo type.")
# -> 2734 return method(
#    2735     repo_id,
#    2736     revision=revision,
#    2737     token=token,
#    2738     timeout=timeout,
#    2739     expand=expand,  # type: ignore[arg-type]
#    2740     files_metadata=files_metadata,
#    2741 )
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/hf_api.py:2519, in HfApi.model_info(self, repo_id, revision, timeout, securityStatus, files_metadata, expand, token)
#    2518 r = get_session().get(path, headers=headers, timeout=timeout, params=params)
# -> 2519 hf_raise_for_status(r)
#    2520 data = r.json()
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/utils/_http.py:481, in hf_raise_for_status(response, endpoint_name)
#     479 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     480 # as well (request id and/or server error message)
# --> 481 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/models/ds4sd/docling-models/revision/v2.1.0 (Request ID: Root=1-67c64430-5599dc922ecd29ff63e14627;5398423f-916a-4b6d-a1f9-6ce2b43fe344)
#
# Invalid credentials in Authorization header
#
# The above exception was the direct cause of the following exception:
#
# LocalEntryNotFoundError                   Traceback (most recent call last)
# Cell In[3], line 5
#       3 source = "https://arxiv.org/pdf/2408.09869"  # document per local path or URL
#       4 converter = DocumentConverter()
# ----> 5 result = converter.convert(source)
#       6 print(result.document.export_to_markdown())  # output: "## Docling Technical Report[...]"
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/pydantic/_internal/_validate_call.py:38, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      36 @functools.wraps(wrapped)
#      37 def wrapper_function(*args, **kwargs):
# ---> 38     return wrapper(*args, **kwargs)
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/pydantic/_internal/_validate_call.py:111, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     110 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# --> 111     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     112     if self.__return_pydantic_validator__:
#     113         return self.__return_pydantic_validator__(res)
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/document_converter.py:212, in DocumentConverter.convert(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     194 @validate_call(config=ConfigDict(strict=True))
#     195 def convert(
#     196     self,
#    (...)
#     202     page_range: PageRange = DEFAULT_PAGE_RANGE,
#     203 ) -> ConversionResult:
#     204     all_res = self.convert_all(
#     205         source=[source],
#     206         raises_on_error=raises_on_error,
#    (...)
#     210         page_range=page_range,
#     211     )
# --> 212     return next(all_res)
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/document_converter.py:235, in DocumentConverter.convert_all(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     232 conv_res_iter = self._convert(conv_input, raises_on_error=raises_on_error)
#     234 had_result = False
# --> 235 for conv_res in conv_res_iter:
#     236     had_result = True
#     237     if raises_on_error and conv_res.status not in {
#     238         ConversionStatus.SUCCESS,
#     239         ConversionStatus.PARTIAL_SUCCESS,
#     240     }:
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/document_converter.py:270, in DocumentConverter._convert(self, conv_input, raises_on_error)
#     261 _log.info(f"Going to convert document batch...")
#     263 # parallel processing only within input_batch
#     264 # with ThreadPoolExecutor(
#     265 #    max_workers=settings.perf.doc_batch_concurrency
#     266 # ) as pool:
#     267 #   yield from pool.map(self.process_document, input_batch)
#     268 # Note: PDF backends are not thread-safe, thread pool usage was disabled.
# --> 270 for item in map(
#     271     partial(self._process_document, raises_on_error=raises_on_error),
#     272     input_batch,
#     273 ):
#     274     elapsed = time.monotonic() - start_time
#     275     start_time = time.monotonic()
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/document_converter.py:311, in DocumentConverter._process_document(self, in_doc, raises_on_error)
#     307 valid = (
#     308     self.allowed_formats is not None and in_doc.format in self.allowed_formats
#     309 )
#     310 if valid:
# --> 311     conv_res = self._execute_pipeline(in_doc, raises_on_error=raises_on_error)
#     312 else:
#     313     error_message = f"File format not allowed: {in_doc.file}"
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/document_converter.py:332, in DocumentConverter._execute_pipeline(self, in_doc, raises_on_error)
#     328 def _execute_pipeline(
#     329     self, in_doc: InputDocument, raises_on_error: bool
#     330 ) -> ConversionResult:
#     331     if in_doc.valid:
# --> 332         pipeline = self._get_pipeline(in_doc.format)
#     333         if pipeline is not None:
#     334             conv_res = pipeline.execute(in_doc, raises_on_error=raises_on_error)
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/document_converter.py:298, in DocumentConverter._get_pipeline(self, doc_format)
#     292 # TODO this will ignore if different options have been defined for the same pipeline class.
#     293 if (
#     294     pipeline_class not in self.initialized_pipelines
#     295     or self.initialized_pipelines[pipeline_class].pipeline_options
#     296     != pipeline_options
#     297 ):
# --> 298     self.initialized_pipelines[pipeline_class] = pipeline_class(
#     299         pipeline_options=pipeline_options
#     300     )
#     301 return self.initialized_pipelines[pipeline_class]
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/pipeline/standard_pdf_pipeline.py:96, in StandardPdfPipeline.__init__(self, pipeline_options)
#      81 if (ocr_model := self.get_ocr_model(artifacts_path=artifacts_path)) is None:
#      82     raise RuntimeError(
#      83         f"The specified OCR kind is not supported: {pipeline_options.ocr_options.kind}."
#      84     )
#      86 self.build_pipe = [
#      87     # Pre-processing
#      88     PagePreprocessingModel(
#      89         options=PagePreprocessingOptions(
#      90             images_scale=pipeline_options.images_scale
#      91         )
#      92     ),
#      93     # OCR
#      94     ocr_model,
#      95     # Layout model
# ---> 96     LayoutModel(
#      97         artifacts_path=artifacts_path,
#      98         accelerator_options=pipeline_options.accelerator_options,
#      99     ),
#     100     # Table structure model
#     101     TableStructureModel(
#     102         enabled=pipeline_options.do_table_structure,
#     103         artifacts_path=artifacts_path,
#     104         options=pipeline_options.table_structure_options,
#     105         accelerator_options=pipeline_options.accelerator_options,
#     106     ),
#     107     # Page assemble
#     108     PageAssembleModel(options=PageAssembleOptions()),
#     109 ]
#     111 # Picture description model
#     112 if (
#     113     picture_description_model := self.get_picture_description_model(
#     114         artifacts_path=artifacts_path
#     115     )
#     116 ) is None:
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/models/layout_model.py:54, in LayoutModel.__init__(self, artifacts_path, accelerator_options)
#      51 device = decide_device(accelerator_options.device)
#      53 if artifacts_path is None:
# ---> 54     artifacts_path = self.download_models() / self._model_path
#      55 else:
#      56     # will become the default in the future
#      57     if (artifacts_path / self._model_repo_folder).exists():
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/docling/models/layout_model.py:89, in LayoutModel.download_models(local_dir, force, progress)
#      87 if not progress:
#      88     disable_progress_bars()
# ---> 89 download_path = snapshot_download(
#      90     repo_id="ds4sd/docling-models",
#      91     force_download=force,
#      92     local_dir=local_dir,
#      93     revision="v2.1.0",
#      94 )
#      96 return Path(download_path)
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Documents/Code/Ai/BeyondNextTokenPrediction/venv/lib/python3.9/site-packages/huggingface_hub/_snapshot_download.py:235, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     232         raise api_call_error
#     233     else:
#     234         # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
# --> 235         raise LocalEntryNotFoundError(
#     236             "An error happened while trying to locate the files on the Hub and we cannot find the appropriate"
#     237             " snapshot folder for the specified revision on the local disk. Please check your internet connection"
#     238             " and try again."
#     239         ) from api_call_error
#     241 # At this stage, internet connection is up and running
#     242 # => let's download the files!
#     243 assert repo_info.sha is not None, "Repo info returned from server must have a revision sha."
#
# LocalEntryNotFoundError: An error happened while trying to locate the files on the Hub and we cannot find the appropriate snapshot folder for the specified revision on the local disk. Please check your internet connection and try again.
